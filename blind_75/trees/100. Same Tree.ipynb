# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
from collections import deque

class Solution:
    def isSameTree(self, p: Optional[TreeNode], q: Optional[TreeNode]) -> bool:
        if not p and not q:
            return True  # Both trees are empty
        if not p or not q:
            return False  # One tree is empty, the other is not
        
        q1 = deque([p])
        q2 = deque([q])
        
        while q1 and q2:
            n1 = q1.popleft()
            n2 = q2.popleft()
            
            # Compare node values
            if n1.val != n2.val:
                return False
            
            # Check left children
            if (n1.left and not n2.left) or (not n1.left and n2.left):
                return False
            if n1.left:
                q1.append(n1.left)
                q2.append(n2.left)
            
            # Check right children
            if (n1.right and not n2.right) or (not n1.right and n2.right):
                return False
            if n1.right:
                q1.append(n1.right)
                q2.append(n2.right)
        
        # Ensure both queues are empty
        return not q1 and not q2

# %% [markdown]
# #### Time and Space Complexity
#
# **Time Complexity**:
# - **O(n)**: Each node in both trees is visited exactly once, where `n` is the total number of nodes in the larger of the two trees.
#
# **Space Complexity**:
# - **O(w)**: The space used by the queues `q1` and `q2`, where `w` is the maximum width of the trees (number of nodes at the widest level).
#   - **Best Case (Balanced Tree)**: O(n) at the maximum level.
#   - **Worst Case (Skewed Tree)**: O(1) since only one child exists per level.

# %% [markdown]
# [![YouTube Video](https://img.youtube.com/vi/vRbbcKXCxOw/0.jpg)](https://www.youtube.com/watch?v=vRbbcKXCxOw)
#
# <iframe width="560" height="315"
#     src="https://www.youtube.com/embed/vRbbcKXCxOw"
#     title="YouTube video player"
#     frameborder="0"
#     allow="accelerometer; autoplay; clipboard-write; encrypted-media; gyroscope; picture-in-picture"
#     allowfullscreen>
# </iframe>
